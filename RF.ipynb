# %%
library('caret')
library('gbm')
library('tidyverse')

x_train = read.delim('Train_call.txt', header = TRUE, sep = "\t", quote = "\"", dec = ".", fill = TRUE, comment.char = "")
y_train = read.delim('Train_clinical.txt', header = TRUE, sep = "\t", quote = "\"", dec = ".", fill = TRUE, comment.char = "", row.names = 1)

x_train = t(x_train)
data <- merge(y_train, x_train[5:nrow(x_train),], by = 'row.names')
row.names(data) <- data$Row.names
data$Row.names <- NULL
set.seed(123)
overall_accuracies = NULL
# outer loop
for (j in seq(1,100)) {
  start_time <- Sys.time()
  msk <- createDataPartition(data[,'Subgroup'], p = 0.8, list = FALSE, times = 1)
  # split the data into training and test set
  dataTrain  <- data[msk, ] # 81 instances
  dataTest <- data[-msk, ]  # 19 instances
  
  rocVarImp <- filterVarImp(dataTrain[, -which(names(dataTrain) == "Subgroup")],
                            factor(dataTrain[, 'Subgroup']) , nonpara = FALSE)
  
  rocVarImpSum <- apply(rocVarImp, 1, sum)
  rocVarImpSum_sorted <- sort(rocVarImpSum, decreasing = TRUE)
  sorted_idx <- strtoi(substring(names(rocVarImpSum_sorted), 2))
  sorted_idx <- paste0('V', sorted_idx)
  write.csv(sorted_idx, file = paste0("random_forest/split", j, ".csv"))
  
  # ---------------------------------------------------------------------------------------
  train_control <- trainControl(method="repeatedcv",
                                number=10,
                                repeats=3,
                                search = "random")
  methods <- c('rf')
  i = 0
  res = NULL # stores results of all models of this split
  
  for (n in seq(56, nrow(dataTrain)+20, 1)) {
    for (method in methods) {
      i = i + 1
      temp_data <- dataTrain[,c('Subgroup', sorted_idx[1:n])] # first n features are used for training
      rf_default <- train(Subgroup ~., data=temp_data, method=method, metric='Accuracy', trControl=train_control)
      res = bind_rows(res, as_tibble(c(rf_default$results[which.max(rf_default$results[,'Accuracy']),], list(split = j, predictors = n, method = 'rf'))))
    }
    
  }
  write.csv(res , file = paste0("random_forest/results_split", j, ".csv"))

  optimal_params <- as.data.frame(res[which.max(as.numeric(unlist(res['Accuracy']))), c('mtry', 'predictors',
                                                                                        'method')])
  print(optimal_params)
  # predictors = features
  
  train_control <- trainControl(method="none")
  tuneGrid = expand.grid(.mtry = optimal_params$mtry)
  
  
  temp_data <- dataTrain[,c('Subgroup', sorted_idx[1:optimal_params[,'predictors']])]
  model2 <- train(Subgroup ~., data = temp_data, method = optimal_params$method, trControl = train_control, 
                  tuneGrid = tuneGrid)
  print(model2)
  
  y_pred = predict(model2, newdata = dataTest[,sorted_idx[1:optimal_params[,'predictors']]])
  
  overall_accuracies = c(overall_accuracies, 
                         confusionMatrix(data = y_pred, as.factor(dataTest[, 'Subgroup']))$overall[['Accuracy']])
  
  ggplot() + 
    geom_line(data = res, aes(x = predictors, y = Accuracy, group = method, color=method)) +
    ylab(label="Accuracy") +
    xlab("Predictors") + 
    ggtitle("Optimized models using random grid search and 10-fold CV\nfor different number of significant predictors in descending order.") + 
    labs(color="Methods")
  ggsave(paste0("random_forest/training_s1_split", j, ".png"))
  end_time <- Sys.time()
  print(end_time - start_time)
  print(paste0('Split ', j , ' done.'))
}
# Out:
# Loading required package: lattice
#
# Loading required package: ggplot2
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.443095 mins
# [1] "Split 29 done."
#   mtry predictors method
# 1   47         58     rf
# Random Forest
#
# 81 samples
# 58 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.27209 mins
# [1] "Split 30 done."
#   mtry predictors method
# 1   54         88     rf
# Random Forest
#
# 81 samples
# 88 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.740183 mins
# [1] "Split 31 done."
#   mtry predictors method
# 1   21         66     rf
# Random Forest
#
# 81 samples
# 66 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.519366 mins
# [1] "Split 32 done."
#   mtry predictors method
# 1   31         98     rf
# Random Forest
#
# 81 samples
# 98 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 10.04092 mins
# [1] "Split 33 done."
#   mtry predictors method
# 1   86         86     rf
# Random Forest
#
# 81 samples
# 86 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.405974 mins
# [1] "Split 34 done."
#   mtry predictors method
# 1   29         94     rf
# Random Forest
#
# 81 samples
# 94 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.277654 mins
# [1] "Split 35 done."
#   mtry predictors method
# 1   32         97     rf
# Random Forest
#
# 81 samples
# 97 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 10.00744 mins
# [1] "Split 36 done."
#   mtry predictors method
# 1   47         79     rf
# Random Forest
#
# 81 samples
# 79 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 10.14994 mins
# [1] "Split 37 done."
#   mtry predictors method
# 1   66         66     rf
# Random Forest
#
# 81 samples
# 66 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.535588 mins
# [1] "Split 38 done."
#   mtry predictors method
# 1   56         86     rf
# Random Forest
#
# 81 samples
# 86 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.171024 mins
# [1] "Split 39 done."
#   mtry predictors method
# 1   64         85     rf
# Random Forest
#
# 81 samples
# 85 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.278155 mins
# [1] "Split 40 done."
#   mtry predictors method
# 1   93         95     rf
# Random Forest
#
# 81 samples
# 95 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.020479 mins
# [1] "Split 41 done."
#   mtry predictors method
# 1   84         92     rf
# Random Forest
#
# 81 samples
# 92 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.087003 mins
# [1] "Split 42 done."
#   mtry predictors method
# 1   59         99     rf
# Random Forest
#
# 81 samples
# 99 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.642907 mins
# [1] "Split 43 done."
#   mtry predictors method
# 1   54         79     rf
# Random Forest
#
# 81 samples
# 79 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.247747 mins
# [1] "Split 44 done."
#   mtry predictors method
# 1   16         98     rf
# Random Forest
#
# 81 samples
# 98 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.367333 mins
# [1] "Split 45 done."
#   mtry predictors method
# 1   41         84     rf
# Random Forest
#
# 81 samples
# 84 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.560762 mins
# [1] "Split 46 done."
#   mtry predictors method
# 1   38         90     rf
# Random Forest
#
# 81 samples
# 90 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.878995 mins
# [1] "Split 47 done."
#   mtry predictors method
# 1   88        101     rf
# Random Forest
#
#  81 samples
# 101 predictors
#   3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 10.16999 mins
# [1] "Split 48 done."
#   mtry predictors method
# 1   58         68     rf
# Random Forest
#
# 81 samples
# 68 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.919905 mins
# [1] "Split 49 done."
#   mtry predictors method
# 1   69         88     rf
# Random Forest
#
# 81 samples
# 88 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.653279 mins
# [1] "Split 50 done."
#   mtry predictors method
# 1   64         89     rf
# Random Forest
#
# 81 samples
# 89 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.995196 mins
# [1] "Split 51 done."
#   mtry predictors method
# 1   51         97     rf
# Random Forest
#
# 81 samples
# 97 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 10.21653 mins
# [1] "Split 52 done."
#   mtry predictors method
# 1   71         99     rf
# Random Forest
#
# 81 samples
# 99 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 10.23373 mins
# [1] "Split 53 done."
#   mtry predictors method
# 1   43         67     rf
# Random Forest
#
# 81 samples
# 67 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 10.20428 mins
# [1] "Split 54 done."
#   mtry predictors method
# 1   27         84     rf
# Random Forest
#
# 81 samples
# 84 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.9668 mins
# [1] "Split 55 done."
#   mtry predictors method
# 1   53         81     rf
# Random Forest
#
# 81 samples
# 81 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 10.56229 mins
# [1] "Split 56 done."
#   mtry predictors method
# 1   22         93     rf
# Random Forest
#
# 81 samples
# 93 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.76529 mins
# [1] "Split 57 done."
#   mtry predictors method
# 1   83         84     rf
# Random Forest
#
# 81 samples
# 84 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.726115 mins
# [1] "Split 58 done."
#   mtry predictors method
# 1   74         93     rf
# Random Forest
#
# 81 samples
# 93 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 10.20659 mins
# [1] "Split 59 done."
#   mtry predictors method
# 1   17         60     rf
# Random Forest
#
# 81 samples
# 60 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.684628 mins
# [1] "Split 60 done."
#   mtry predictors method
# 1   97         97     rf
# Random Forest
#
# 81 samples
# 97 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 11.48215 mins
# [1] "Split 61 done."
#   mtry predictors method
# 1   78         92     rf
# Random Forest
#
# 81 samples
# 92 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 11.05773 mins
# [1] "Split 62 done."
#   mtry predictors method
# 1   92         94     rf
# Random Forest
#
# 81 samples
# 94 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 10.32981 mins
# [1] "Split 63 done."
#   mtry predictors method
# 1   21         94     rf
# Random Forest
#
# 81 samples
# 94 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 10.05834 mins
# [1] "Split 64 done."
#   mtry predictors method
# 1   67         77     rf
# Random Forest
#
# 81 samples
# 77 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 10.05865 mins
# [1] "Split 65 done."
#   mtry predictors method
# 1   73         73     rf
# Random Forest
#
# 81 samples
# 73 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.784821 mins
# [1] "Split 66 done."
#   mtry predictors method
# 1   33        100     rf
# Random Forest
#
#  81 samples
# 100 predictors
#   3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.855184 mins
# [1] "Split 67 done."
#   mtry predictors method
# 1   37         95     rf
# Random Forest
#
# 81 samples
# 95 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.893297 mins
# [1] "Split 68 done."
#   mtry predictors method
# 1   58         84     rf
# Random Forest
#
# 81 samples
# 84 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 10.44136 mins
# [1] "Split 69 done."
#   mtry predictors method
# 1   95         96     rf
# Random Forest
#
# 81 samples
# 96 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.896999 mins
# [1] "Split 70 done."
#   mtry predictors method
# 1   77         84     rf
# Random Forest
#
# 81 samples
# 84 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 10.05326 mins
# [1] "Split 71 done."
#   mtry predictors method
# 1   48         88     rf
# Random Forest
#
# 81 samples
# 88 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 10.09494 mins
# [1] "Split 72 done."
#   mtry predictors method
# 1   64         65     rf
# Random Forest
#
# 81 samples
# 65 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.546575 mins
# [1] "Split 73 done."
#   mtry predictors method
# 1   75         87     rf
# Random Forest
#
# 81 samples
# 87 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.502001 mins
# [1] "Split 74 done."
#   mtry predictors method
# 1   38         62     rf
# Random Forest
#
# 81 samples
# 62 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 10.40684 mins
# [1] "Split 75 done."
#   mtry predictors method
# 1   51         79     rf
# Random Forest
#
# 81 samples
# 79 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.564273 mins
# [1] "Split 76 done."
#   mtry predictors method
# 1   94         94     rf
# Random Forest
#
# 81 samples
# 94 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 10.30617 mins
# [1] "Split 77 done."
#   mtry predictors method
# 1   16         94     rf
# Random Forest
#
# 81 samples
# 94 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 10.41242 mins
# [1] "Split 78 done."
#   mtry predictors method
# 1   97        100     rf
# Random Forest
#
#  81 samples
# 100 predictors
#   3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 10.00365 mins
# [1] "Split 79 done."
#   mtry predictors method
# 1   37         56     rf
# Random Forest
#
# 81 samples
# 56 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.207219 mins
# [1] "Split 80 done."
#   mtry predictors method
# 1   89         92     rf
# Random Forest
#
# 81 samples
# 92 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 8.858498 mins
# [1] "Split 81 done."
#   mtry predictors method
# 1   60        100     rf
# Random Forest
#
#  81 samples
# 100 predictors
#   3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.1387 mins
# [1] "Split 82 done."
#   mtry predictors method
# 1   71        101     rf
# Random Forest
#
#  81 samples
# 101 predictors
#   3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.286968 mins
# [1] "Split 83 done."
#   mtry predictors method
# 1   50        101     rf
# Random Forest
#
#  81 samples
# 101 predictors
#   3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.489546 mins
# [1] "Split 84 done."
#   mtry predictors method
# 1   23         89     rf
# Random Forest
#
# 81 samples
# 89 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 8.875762 mins
# [1] "Split 85 done."
#   mtry predictors method
# 1   54         81     rf
# Random Forest
#
# 81 samples
# 81 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 8.714974 mins
# [1] "Split 86 done."
#   mtry predictors method
# 1   27         75     rf
# Random Forest
#
# 81 samples
# 75 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.126889 mins
# [1] "Split 87 done."
#   mtry predictors method
# 1   54         73     rf
# Random Forest
#
# 81 samples
# 73 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.117871 mins
# [1] "Split 88 done."
#   mtry predictors method
# 1   44         74     rf
# Random Forest
#
# 81 samples
# 74 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.257034 mins
# [1] "Split 89 done."
#   mtry predictors method
# 1   33         69     rf
# Random Forest
#
# 81 samples
# 69 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.136463 mins
# [1] "Split 90 done."
#   mtry predictors method
# 1   74         91     rf
# Random Forest
#
# 81 samples
# 91 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.185651 mins
# [1] "Split 91 done."
#   mtry predictors method
# 1   67         88     rf
# Random Forest
#
# 81 samples
# 88 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.120924 mins
# [1] "Split 92 done."
#   mtry predictors method
# 1   91         91     rf
# Random Forest
#
# 81 samples
# 91 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 8.905057 mins
# [1] "Split 93 done."
#   mtry predictors method
# 1   26         61     rf
# Random Forest
#
# 81 samples
# 61 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 8.981905 mins
# [1] "Split 94 done."
#   mtry predictors method
# 1   30         80     rf
# Random Forest
#
# 81 samples
# 80 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.177006 mins
# [1] "Split 95 done."
#   mtry predictors method
# 1   73         74     rf
# Random Forest
#
# 81 samples
# 74 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.549496 mins
# [1] "Split 96 done."
#   mtry predictors method
# 1   52         88     rf
# Random Forest
#
# 81 samples
# 88 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.043682 mins
# [1] "Split 97 done."
#   mtry predictors method
# 1   23         59     rf
# Random Forest
#
# 81 samples
# 59 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.10562 mins
# [1] "Split 98 done."
#   mtry predictors method
# 1   61         98     rf
# Random Forest
#
# 81 samples
# 98 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.245393 mins
# [1] "Split 99 done."
#   mtry predictors method
# 1   22         91     rf
# Random Forest
#
# 81 samples
# 91 predictors
#  3 classes: 'HER2+', 'HR+', 'Triple Neg'
#
# No pre-processing
# Resampling: None
# Saving 6.67 x 6.67 in image
#
# Time difference of 9.31929 mins
# [1] "Split 100 done."

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=39982db8-5b4c-4eff-a4a1-5a43e95600e9' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
